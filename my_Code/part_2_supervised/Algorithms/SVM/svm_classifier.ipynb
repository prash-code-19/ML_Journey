# %% [markdown]
# ***
# # SUPPORT VECTOR MACHINE
# ***

# %%
# Both Classification and Regression can be solved

# %%
# Margin Hyperplane is:
        # equi_distant from Decision Boundary
        # parallel too each other

# Margin value = DISTANCE BETWEEN MARGIN HYPERPLANES

# more is the margin value better to classify the clases

# %%
# Clearly/ perfectly Separable classes : HARD MARGIN SVM

# account for classification errors (since classes are not clearly separable) 
# Using Changed Mathematical equation : soft Margin SVM

# %%
# minimize (||w|| ^ 2) /2

# yi * (wT*x + b) >= 1 =>> constraint

# %%
# CLASSIFICATION

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
df = datasets.load_iris(as_frame= True).frame

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X= df.drop("target", axis =1)
y = df["target"]

# %%
X_train, X_test, y_train,y_test = train_test_split(
    X,y, test_size = 0.3, random_state  = 42, stratify=y # stratify used for imbalanced class : preserves proportion of each calss in train and test
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# MODEL

svc = SVC()

svc.fit(X_train_scaled, y_train)
# Out:
# SVC()

# %%
y_pred = svc.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score as acs, classification_report as crt

print("accuracy" , acs(y_pred, y_test))
# Out:
# accuracy 0.9333333333333333

# %%
# LINEAR KERNAL

svc = SVC(kernel = "linear")
svc.fit(X_train_scaled,y_train)

y_pred = svc.predict(X_test_scaled)

print("accuracy" , acs(y_test, y_pred))
# Out:
# accuracy 0.9111111111111111

# %%
# POLYNOMIAL KERNAL

svc = SVC(kernel = "poly")
svc.fit(X_train_scaled,y_train)

y_pred = svc.predict(X_test_scaled)

print("accuracy" , acs(y_test, y_pred))
# Out:
# accuracy 0.8666666666666667

# %%
# SIGMOID KERNAL

svc = SVC(kernel = "sigmoid")
svc.fit(X_train_scaled,y_train)

y_pred = svc.predict(X_test_scaled)

print("accuracy" , acs(y_test, y_pred))
# Out:
# accuracy 0.9111111111111111

# %%
# check for different C Values

C_vals = [0.5,1,2,3,4,5]

for val in C_vals:
    svc = SVC(kernel = "rbf", C=val)
    svc.fit(X_train_scaled,y_train)
    
    y_pred = svc.predict(X_test_scaled)
    
    print("C = ",val,"& accuracy" , acs(y_test, y_pred))
# Out:
# C =  0.5 & accuracy 0.9111111111111111
# C =  1 & accuracy 0.9333333333333333
# C =  2 & accuracy 0.9111111111111111
# C =  3 & accuracy 0.9111111111111111
# C =  4 & accuracy 0.9333333333333333
# C =  5 & accuracy 0.9333333333333333
